# %%
import cv2

# %%
img= cv2.imread("background.jpg")

# %%
img.shape
# Out:
# (1439, 1302, 3)

# %%
img=cv2.resize(img,(500,500))
cv2.imshow("LUFFY",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
hsv_img=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
cv2.imshow("LUFFY",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
canny_img=cv2.Canny(img,100,200)
cv2.imshow("LUFFY",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
vid=cv2.VideoCapture(0)

while True:
    res,frame=vid.read()
    frame=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2.imshow("Camera",frame)
    if cv2.waitKey(1) & 0xFF==ord("q"):
        break
vid.release()
cv2.destroyAllWindows()

# %%
#For simple face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
vid=cv2.VideoCapture(0)
while True:
    res,frame=vid.read()
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces=face_cascade.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=4)
    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w , y+h),(255,0,0),2)
    cv2.imshow("Camera",frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
vid.release()
cv2.destroyAllWindows()
# Out:
# [[131 128 127 ... 193 195 201]
#  [129 129 129 ... 196 195 198]
#  [131 132 132 ... 205 203 206]
#  ...
#  [ 94  96  96 ... 118 116 117]
#  [ 90  93  95 ... 119 117 116]
#  [ 87  90  94 ... 119 117 116]]
# [[138 140 139 ... 208 210 215]
#  [139 140 138 ... 214 211 210]
#  [138 138 135 ... 220 219 218]
#  ...
#  [109 108 111 ... 133 132 132]
#  [104 104 107 ... 132 132 133]
#  [103 104 105 ... 131 133 135]]
# [[133 133 132 ... 212 215 214]
#  [131 131 130 ... 215 216 215]
#  [132 132 132 ... 222 224 223]
#  ...
#  [109 113 117 ... 132 131 131]
#  [104 105 108 ... 130 130 131]
#  [101 101 103 ... 131 132 134]]
# [[134 133 131 ... 201 207 218]
#  [137 133 129 ... 207 213 217]
#  [131 130 131 ... 218 223 222]
#  ...
#  [106 105 108 ... 137 137 138]
#  [105 104 106 ... 135 136 137]
#  [106 101 104 ... 134 135 136]]
# [[141 138 137 ... 208 214 217]
#  [140 138 138 ... 213 216 216]
#  [140 137 137 ... 218 216 213]
#  ...
#  [106 111 111 ... 139 139 140]
#  [103 109 108 ... 137 139 139]
#  [101 102 103 ... 134 140 140]]
# [[134 139 142 ... 210 209 211]
#  [132 136 138 ... 209 211 213]
#  [135 137 137 ... 214 221 223]
#  ...
#  [105 107 113 ... 132 134 135]
#  [ 95  98 105 ... 131 135 135]
#  [ 91  90 101 ... 131 138 136]]
# [[135 133 135 ... 207 212 215]
#  [135 135 136 ... 211 214 213]
#  [135 135 136 ... 220 222 220]
#  ...
#  [113 116 115 ... 139 140 140]
#  [104 109 112 ... 138 140 141]
#  [101 105 112 ... 138 138 138]]
# [[135 133 134 ... 210 212 214]
#  [136 136 137 ... 206 210 212]
#  [139 140 140 ... 213 217 219]
#  ...
#  [104 108 112 ... 136 136 135]
#  [105 105 106 ... 136 138 140]
#  [ 97 101 106 ... 141 142 142]]
# [[138 140 140 ... 210 210 215]
